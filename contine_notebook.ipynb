# %% [markdown]
# # Topic Clarification
# This notebook is scaffolded to support a concrete topic. Set `TOPIC` to a specific subject before running further analysis.

# %%
# Section 1: Clarify Notebook Topic
TOPIC = None
if not TOPIC or TOPIC == 'contine':
    raise ValueError(
        'Please set TOPIC to the concrete notebook subject (e.g., "image classification" or "time series forecasting").'
    )

print(f'Notebook topic is: {TOPIC}')

# %% [markdown]
# # Section 2: Environment Setup
# Set up required packages and imports for the notebook runtime.
